# %%
import numpy as np
import sklearn
import sklearn.linear_model
from sklearn import preprocessing
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from torch import optim
import os
import gc
from datetime import datetime

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
class Module(nn.Module):
    def __init__(self, final_dim):
        super().__init__()
        self.inp = nn.Linear(1024, 512)
        self.outp1 = nn.Linear(512, 256)
        self.outp2 = nn.Linear(256, 128)
        self.outp3 = nn.Linear(128, 64)
        self.outp4 = nn.Linear(64, final_dim)
        self.drop = nn.Dropout(0.2)
    def forward(self, x):
        x = self.inp(x)
        x = F.relu(x)
        x = self.outp1(x)
        x = F.relu(x)
        x = self.outp2(x)
        x = F.relu(x)
        x = self.outp3(x)
        x = F.relu(x)
        x = self.drop(x)
        x = torch.sigmoid(x)
        x = self.outp4(x)
        return x

# %%
def load_ds(dataset, mode):
    train_rep = np.load(dataset[0])
    train_lab = np.load(dataset[1])
    valid_rep = np.load(dataset[2])
    valid_lab = np.load(dataset[3])

    train_tar = []
    valid_tar = []
    if mode == 'binary':
        labels = [set(('I-PER', 'B-PER')), set(('O', 'I-ORG', 'B-ORG', 'I-LOC', 'B-LOC', 'I-MISC', 'B-MISC'))]
    else:
        labels = [set(('I-PER', 'B-PER')), set(('O')), set(('I-MISC', 'B-MISC')), set(('I-LOC', 'B-LOC')), set(('I-ORG', 'B-ORG'))]
    for lab in labels:
        train_tar.append([1 if x in lab else 0 for x in train_lab])
        valid_tar.append([1 if x in lab else 0 for x in valid_lab])
    train_tar = np.array(train_tar).T
    valid_tar = np.array(valid_tar).T

    train_rep, train_tar = map(torch.tensor, (train_rep, train_tar))
    valid_rep, valid_tar = map(torch.tensor, (valid_rep, valid_tar))

    return train_rep, train_tar, valid_rep, valid_tar

# %%
def train(model, train_dl, valid_dl, loss_func, opt, epochs=20):
    if torch.cuda.is_available():
        model.cuda()
        
    prev_loss = -1
    train_dl = train_dl
    for epoch in range(epochs):
        model.train()
        for xb, yb in train_dl:
            xb = xb.to('cuda')
            yb = yb.to('cuda')
            pred = model(xb)
            loss = loss_func(pred, torch.argmax(yb, dim=1))

            loss.backward()
            opt.step()
            opt.zero_grad()

        model.eval()
        with torch.no_grad():
            valid_loss = sum(loss_func(model(xb.to('cuda')), torch.argmax(yb.to('cuda'), dim=1)) for xb, yb in valid_dl) / len(valid_dl)
            if abs(valid_loss - prev_loss) < 1e-5:
                break
            prev_loss = valid_loss

        print(epoch, valid_loss)

# %%
def avaliate(dataset, mode='binary'):
    train_rep, train_tar, valid_rep, valid_tar = load_ds(dataset, mode)
    train_d = TensorDataset(train_rep, train_tar)
    train_d = DataLoader(train_d, batch_size=128, pin_memory=True)
    valid_d = TensorDataset(valid_rep, valid_tar)
    valid_d = DataLoader(valid_d, batch_size=128, pin_memory=True)

    model = Module(2 if mode == 'binary' else 5)
    loss = F.cross_entropy
    opt = optim.SGD(model.parameters(), lr=0.01)

    if mode == 'binary':
        n_epochs = 40
    else:
        n_epochs = 80
    
    t = datetime.now()
    train(model, train_d, valid_d, loss, opt, n_epochs)
    print('Time for the train step:', datetime.now() - t)

    t = datetime.now()
    model.eval()
    model.cpu()
    pred = torch.argmax(model(valid_rep), dim=1)
    pred = pred.detach().numpy()
    valid_tar = torch.argmax(valid_tar, dim=1)
    valid_tar = valid_tar.detach().numpy()
    print('Time for the analysis step:', datetime.now() - t)

    conf_matrix = sklearn.metrics.confusion_matrix(valid_tar, pred)
    
    valid_tar = np.array([valid_tar == 0], dtype=int).T
    pred = np.array([pred == 0], dtype=int).T

    precision = sklearn.metrics.precision_score(valid_tar, pred)
    accuracy = sklearn.metrics.accuracy_score(valid_tar, pred)
    f_score = sklearn.metrics.f1_score(valid_tar, pred)

    print('CONFUSION MATRIX:')
    print(conf_matrix)

    print('OVERALL ACCURACY:', accuracy)
    print('TRUE POSITIVE RATE:', precision)
    print('F-SCORE:', precision)

# %%
gc.collect()
os.chdir('/kaggle/input')
dataset_paths = {'english_a': ['engdataset/data/representation.train.npy', 'engdataset/data/true_labels.train.npy', 'engdataset/data/representation.testa.npy', 'engdataset/data/true_labels.testa.npy'],
                 'english_b': ['engdataset/data/representation.train.npy', 'engdataset/data/true_labels.train.npy', 'engdataset/data/representation.testb.npy', 'engdataset/data/true_labels.testb.npy'],
                 'spanish': ['pi-inf442/representation.esp.train.npy', 'pi-inf442/true_labels.esp.train.npy', 'pi-inf442/representation.esp.testa.npy', 'pi-inf442/true_labels.esp.testa.npy'], 
                 'dutch': ['pi-inf442/representation.ned.train.npy', 'pi-inf442/true_labels.ned.train.npy', 'pi-inf442/representation.ned.testa.npy', 'pi-inf442/true_labels.ned.testa.npy'],
                 'portuguese': ['pi-inf442/representation.portuguese.train.npy', 'pi-inf442/true_labels.portuguese.train.npy', 'pi-inf442/representation.portuguese.test.npy', 'pi-inf442/true_labels.portuguese.test.npy']}

for language in dataset_paths:
    print(language)
    avaliate(dataset_paths[language])
    if language == 'english_a' or language == 'english_b':
        print(language, 'ner')
        avaliate(dataset_paths[language], 'ner')
# Out:
# english_a
# 0 tensor(0.2380, device='cuda:0')
# 1 tensor(0.2379, device='cuda:0')
# 2 tensor(0.2376, device='cuda:0')
# 3 tensor(0.2373, device='cuda:0')
# 4 tensor(0.2364, device='cuda:0')
# 5 tensor(0.2344, device='cuda:0')
# 6 tensor(0.2274, device='cuda:0')
# 7 tensor(0.1958, device='cuda:0')
# 8 tensor(0.1268, device='cuda:0')
# 9 tensor(0.0700, device='cuda:0')
# 10 tensor(0.0503, device='cuda:0')
# 11 tensor(0.0431, device='cuda:0')
# 12 tensor(0.0392, device='cuda:0')
# 13 tensor(0.0374, device='cuda:0')
# 14 tensor(0.0354, device='cuda:0')
# 15 tensor(0.0343, device='cuda:0')
# 16 tensor(0.0335, device='cuda:0')
# 13 tensor(0.0422, device='cuda:0')
# 14 tensor(0.0396, device='cuda:0')
# 15 tensor(0.0379, device='cuda:0')
# 16 tensor(0.0363, device='cuda:0')
# 17 tensor(0.0358, device='cuda:0')
# 18 tensor(0.0350, device='cuda:0')
# 19 tensor(0.0346, device='cuda:0')
# 20 tensor(0.0345, device='cuda:0')
# 21 tensor(0.0345, device='cuda:0')
# 22 tensor(0.0348, device='cuda:0')
# 23 tensor(0.0344, device='cuda:0')
# 24 tensor(0.0344, device='cuda:0')
# 25 tensor(0.0344, device='cuda:0')
# 26 tensor(0.0347, device='cuda:0')
# 27 tensor(0.0348, device='cuda:0')
# 28 tensor(0.0350, device='cuda:0')
# 29 tensor(0.0355, device='cuda:0')
# 30 tensor(0.0348, device='cuda:0')
# 31 tensor(0.0352, device='cuda:0')
# 32 tensor(0.0360, device='cuda:0')
# 33 tensor(0.0356, device='cuda:0')
# 34 tensor(0.0369, device='cuda:0')
# 35 tensor(0.0365, device='cuda:0')
# 36 tensor(0.0370, device='cuda:0')
# 37 tensor(0.0377, device='cuda:0')
# 38 tensor(0.0375, device='cuda:0')
# 39 tensor(0.0366, device='cuda:0')
# Time for the train step: 0:03:20.829269
# Time for the analysis step: 0:00:00.738071
# CONFUSION MATRIX:
# [[ 2397   372]
#  [  157 43491]]
# OVERALL ACCURACY: 0.9886033134411961
# TRUE POSITIVE RATE: 0.9385277995301488
# F-SCORE: 0.9385277995301488
# english_b ner
# 0 tensor(0.6986, device='cuda:0')
# 1 tensor(0.6969, device='cuda:0')
# 2 tensor(0.6879, device='cuda:0')
# 3 tensor(0.5334, device='cuda:0')
# 4 tensor(0.3540, device='cuda:0')
# 5 tensor(0.3172, device='cuda:0')
# 6 tensor(0.3059, device='cuda:0')
# 7 tensor(0.3006, device='cuda:0')
# 8 tensor(0.2979, device='cuda:0')
# 9 tensor(0.2959, device='cuda:0')
# 10 tensor(0.2943, device='cuda:0')
# 11 tensor(0.2929, device='cuda:0')
# 12 tensor(0.2914, device='cuda:0')
# 13 tensor(0.2902, device='cuda:0')
# 14 tensor(0.2881, device='cuda:0')
# 15 tensor(0.2831, device='cuda:0')
# 16 tensor(0.2768, device='cuda:0')
# 17 tensor(0.2691, device='cuda:0')
# 18 tensor(0.2594, device='cuda:0')
# 19 tensor(0.2502, device='cuda:0')
# 20 tensor(0.2406, device='cuda:0')
# 21 tensor(0.2336, device='cuda:0')
# 22 tensor(0.2243, device='cuda:0')
# 23 tensor(0.2188, device='cuda:0')
# 24 tensor(0.2115, device='cuda:0')
# 25 tensor(0.2052, device='cuda:0')
# 26 tensor(0.1996, device='cuda:0')
# 27 tensor(0.1954, device='cuda:0')
# 28 tensor(0.1879, device='cuda:0')
# 29 tensor(0.1828, device='cuda:0')
# 30 tensor(0.1791, device='cuda:0')
# 31 tensor(0.1734, device='cuda:0')
# 8 tensor(0.0483, device='cuda:0')
# 9 tensor(0.0440, device='cuda:0')
# 10 tensor(0.0421, device='cuda:0')
# 11 tensor(0.0414, device='cuda:0')
# 12 tensor(0.0413, device='cuda:0')
# 13 tensor(0.0410, device='cuda:0')
# 14 tensor(0.0405, device='cuda:0')
# 15 tensor(0.0420, device='cuda:0')
# 16 tensor(0.0408, device='cuda:0')
# 17 tensor(0.0410, device='cuda:0')
# 18 tensor(0.0424, device='cuda:0')
# 19 tensor(0.0416, device='cuda:0')
# 20 tensor(0.0426, device='cuda:0')
# 21 tensor(0.0406, device='cuda:0')
# 22 tensor(0.0413, device='cuda:0')
# 23 tensor(0.0409, device='cuda:0')
# 24 tensor(0.0411, device='cuda:0')
# 25 tensor(0.0447, device='cuda:0')
# 26 tensor(0.0427, device='cuda:0')
# 27 tensor(0.0423, device='cuda:0')
# 28 tensor(0.0420, device='cuda:0')
# 29 tensor(0.0419, device='cuda:0')
# 30 tensor(0.0419, device='cuda:0')
# 31 tensor(0.0433, device='cuda:0')
# 32 tensor(0.0410, device='cuda:0')
# 33 tensor(0.0432, device='cuda:0')
# 34 tensor(0.0419, device='cuda:0')
# 35 tensor(0.0408, device='cuda:0')
# 36 tensor(0.0438, device='cuda:0')
# 37 tensor(0.0411, device='cuda:0')
# 38 tensor(0.0417, device='cuda:0')
# 39 tensor(0.0418, device='cuda:0')
# Time for the train step: 0:04:12.989760
# Time for the analysis step: 0:00:00.792146
# CONFUSION MATRIX:
# [[ 1762   300]
#  [  461 49760]]
# OVERALL ACCURACY: 0.9854445995830384
# TRUE POSITIVE RATE: 0.7926225820962663
# F-SCORE: 0.7926225820962663
# dutch
# 0 tensor(0.1346, device='cuda:0')
# 1 tensor(0.1343, device='cuda:0')
# 2 tensor(0.1338, device='cuda:0')
# 3 tensor(0.1325, device='cuda:0')
# 4 tensor(0.1290, device='cuda:0')
# 5 tensor(0.1194, device='cuda:0')
# 6 tensor(0.1044, device='cuda:0')
# 7 tensor(0.0881, device='cuda:0')
# 8 tensor(0.0735, device='cuda:0')
# 9 tensor(0.0609, device='cuda:0')
# 10 tensor(0.0509, device='cuda:0')
# 11 tensor(0.0444, device='cuda:0')
# 12 tensor(0.0412, device='cuda:0')
# 13 tensor(0.0397, device='cuda:0')
# 14 tensor(0.0383, device='cuda:0')
# 15 tensor(0.0374, device='cuda:0')
# 16 tensor(0.0370, device='cuda:0')
# 17 tensor(0.0367, device='cuda:0')
# 18 tensor(0.0358, device='cuda:0')
# 19 tensor(0.0353, device='cuda:0')
# 20 tensor(0.0349, device='cuda:0')
# 21 tensor(0.0343, device='cuda:0')
# 22 tensor(0.0340, device='cuda:0')
# 23 tensor(0.0339, device='cuda:0')
# 24 tensor(0.0337, device='cuda:0')
# 25 tensor(0.0334, device='cuda:0')
# 26 tensor(0.0329, device='cuda:0')
# 27 tensor(0.0333, device='cuda:0')
# 28 tensor(0.0331, device='cuda:0')
# 29 tensor(0.0330, device='cuda:0')
# 30 tensor(0.0336, device='cuda:0')
# 31 tensor(0.0330, device='cuda:0')
# 32 tensor(0.0333, device='cuda:0')
# 33 tensor(0.0336, device='cuda:0')
# 34 tensor(0.0334, device='cuda:0')
# 35 tensor(0.0332, device='cuda:0')
# 36 tensor(0.0335, device='cuda:0')
# 37 tensor(0.0337, device='cuda:0')
# 38 tensor(0.0336, device='cuda:0')
# 39 tensor(0.0339, device='cuda:0')
# Time for the train step: 0:03:14.105835
# Time for the analysis step: 0:00:00.584671
# CONFUSION MATRIX:
# [[  859   267]
#  [  126 36354]]
# OVERALL ACCURACY: 0.9895495399670265
# TRUE POSITIVE RATE: 0.8720812182741117
# F-SCORE: 0.8720812182741117
# portuguese
# 0 tensor(0.0789, device='cuda:0')
# 1 tensor(0.0789, device='cuda:0')
# 2 tensor(0.0788, device='cuda:0')
# 3 tensor(0.0786, device='cuda:0')
# 4 tensor(0.0784, device='cuda:0')
# 5 tensor(0.0780, device='cuda:0')
# 6 tensor(0.0774, device='cuda:0')
# 7 tensor(0.0761, device='cuda:0')
# 8 tensor(0.0735, device='cuda:0')
# 9 tensor(0.0685, device='cuda:0')
# 10 tensor(0.0610, device='cuda:0')
# 11 tensor(0.0527, device='cuda:0')
# 12 tensor(0.0447, device='cuda:0')
# 13 tensor(0.0368, device='cuda:0')
# 14 tensor(0.0299, device='cuda:0')
# 15 tensor(0.0254, device='cuda:0')
# 16 tensor(0.0230, device='cuda:0')
# 17 tensor(0.0217, device='cuda:0')
# 18 tensor(0.0209, device='cuda:0')
# 19 tensor(0.0204, device='cuda:0')
# 20 tensor(0.0199, device='cuda:0')
# 21 tensor(0.0196, device='cuda:0')
# 22 tensor(0.0193, device='cuda:0')
# 23 tensor(0.0190, device='cuda:0')
# 24 tensor(0.0190, device='cuda:0')
# 25 tensor(0.0186, device='cuda:0')
# 26 tensor(0.0187, device='cuda:0')
# 27 tensor(0.0186, device='cuda:0')
# 28 tensor(0.0184, device='cuda:0')
# 29 tensor(0.0182, device='cuda:0')
# 30 tensor(0.0180, device='cuda:0')
# 31 tensor(0.0180, device='cuda:0')
# 32 tensor(0.0178, device='cuda:0')
# 33 tensor(0.0176, device='cuda:0')
# 34 tensor(0.0177, device='cuda:0')
# 35 tensor(0.0177, device='cuda:0')
# 36 tensor(0.0177, device='cuda:0')
# 37 tensor(0.0175, device='cuda:0')
# 38 tensor(0.0173, device='cuda:0')
# 39 tensor(0.0173, device='cuda:0')
# Time for the train step: 0:03:11.398160
# Time for the analysis step: 0:00:00.586173
# CONFUSION MATRIX:
# [[  476   126]
#  [   74 38867]]
# OVERALL ACCURACY: 0.9949422148041372
# TRUE POSITIVE RATE: 0.8654545454545455
# F-SCORE: 0.8654545454545455
